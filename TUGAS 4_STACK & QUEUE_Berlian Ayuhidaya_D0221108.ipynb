# %%
#Membuat Stack
def buat_stack_():
    stack = [10,15,20]
    return stack

#memeriksa apakah stack kosong
def check_empty(stack):
    return len(stack) == 0

#Menambhakan item pada posisi teratas
def push(stack, item):
    stack.append(item)
    print("Kode Buku Pemprograman Python yang dikembalikan:",item)

#Menghapus item pada posisi teratas
def pop(stack):
    if (check_empty(stack)):
        return print("Buku pada rak kosong")
    print("Kode Buku Pemprograman Python yang dipinjam:",stack.pop())
    
#menghitung elemen stack
def size(stack):
    print("Jumlah Buku Pemprograman Python yang ada di Rak :",len(stack))
    
#menentukan posisi element paling atas
def top(stack):
    top = len(stack)-1
    if top <0:
        print("Tidak Terdefenisi")
    else:
        print("Kode Buku Pemprograman Python Teratas :",stack[top])
        
#menampilkan hasil stack
def tampilkan(stack):
    print(stack)
    
s = buat_stack()
print("=============================================================")
print("||                 PERPUSTAKAAN UNSULBAR                   ||")
print("||--------Tumpukan Buku Pemprograman Python Pada Rak-------||")
print("=============================================================")

#Data Awal Pada Stack
print("kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini :",s)
top(s)
size(s)
print()

#Meminjam buku
pop(s)
pop(s)
pop(s)
print("Kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini :",s)
top(s)
size(s)
print()

#Mengembalikan Buku
push(s,input())
push(s,input())
push(s,input())
print("Kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini:",s )
# Out:
# ...
# ||                 PERPUSTAKAAN UNSULBAR                   ||
# ||--------Tumpukan Buku Pemprograman Python Pada Rak-------||
# ...
# kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini : [10, 15]
# Kode Buku Pemprograman Python Teratas : 15
# Jumlah Buku Pemprograman Python yang ada di Rak : 2
#
# Kode Buku Pemprograman Python yang dipinjam: 15
# Kode Buku Pemprograman Python yang dipinjam: 10
# Buku pada rak kosong
# Kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini : []
# Tidak Terdefenisi
# Jumlah Buku Pemprograman Python yang ada di Rak : 0
#
# 4
# Kode Buku Pemprograman Python yang dikembalikan: 4
# 6
# Kode Buku Pemprograman Python yang dikembalikan: 6
# 8
# Kode Buku Pemprograman Python yang dikembalikan: 8
# Kode Buku Pemprograman Python yang berada pada tumpukan Rak saat ini: ['4', '6', '8']

# %%
# Membuat Queue

queue = []
max_size = int(input("Masukkan Ukuran Maksimal Queue:"))

def isEmpty():
  if len(queue) == 0:
    print("Queue Kosong.")
    return True
  return False

def isFull():
  if len(queue) == max_size:
    print("Queue Penuh.")
    return True
  return False

def dequeue():
  if isEmpty() == False:
    print(queue.pop(0),"terhapus dari queue.")
    
def enqueu():
  if isFull() == False:
    x = input("Masukkan Antrian Baru:")
    queue.append(x)
    print(x,"ditambahkan ke queue.")
    
p = 0
while p !='5':
    print('''\n1.Enqueue => Menambah Antrian
2. Dequeue => Menghapus dari Antrian
3. Full => Memeriksa Apakah Queue Penuh
4. Size => Melihat Ukuran Queue''')
    p = input("Ketik 5 untuk berhenti\nMasukkan Perintah:")
    print()
       
    if p == '1':
      enqueu()
    elif p == '2':
      dequeue()
    elif p == '3':
      if isFull() == False:
         print("Queue belum penuh.")
    elif p == '4':
      print("Ukuran queue saat ini:",len(queue),"\nUkuran maksimal queue:",max_size)
# Out:
# Masukkan Ukuran Maksimal Queue:4
#
# 1.Enqueue => Menambah Antrian
# 2. Dequeue => Menghapus dari Antrian
# 3. Full => Memeriksa Apakah Queue Penuh
# 4. Size => Melihat Ukuran Queue
# Ketik 5 untuk berhenti
# Masukkan Perintah:1
#
# Masukkan Antrian Baru:2
# 2 ditambahkan ke queue.
#
# 1.Enqueue => Menambah Antrian
# 2. Dequeue => Menghapus dari Antrian
# 3. Full => Memeriksa Apakah Queue Penuh
# 4. Size => Melihat Ukuran Queue
# Ketik 5 untuk berhenti
# Masukkan Perintah:2
#
# 2 terhapus dari queue.
#
# 1.Enqueue => Menambah Antrian
# 2. Dequeue => Menghapus dari Antrian
# 3. Full => Memeriksa Apakah Queue Penuh
# 4. Size => Melihat Ukuran Queue
# Ketik 5 untuk berhenti
# Masukkan Perintah:1
#
# Masukkan Antrian Baru:5
# 5 ditambahkan ke queue.
#
# 1.Enqueue => Menambah Antrian
# 2. Dequeue => Menghapus dari Antrian
# 3. Full => Memeriksa Apakah Queue Penuh
# 4. Size => Melihat Ukuran Queue
# Ketik 5 untuk berhenti
# Masukkan Perintah:3
#
# Queue belum penuh.
#
# ...
